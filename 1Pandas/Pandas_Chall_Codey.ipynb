# %%
# Codey's challenges Pandas
import pandas as pd

products = pd.read_csv(r"D:\Internshala BI\M5-20251101T095706Z-1-001\M5\products.csv")

# %%
products
# Out:
#   Product_ID      Product_Name     Category  Price  Stock_Quantity
# 0       P001            Laptop  Electronics    800              50
# 1       P002        Smartphone  Electronics    600             200
# 2       P003      Office Chair    Furniture    150             100
# 3       P004          Notebook   Stationery      5             500
# 4       P005  Wireless Headset  Electronics    100             150

# %%
products.head() #Display first 5 rows
# Out:
#   Product_ID      Product_Name     Category  Price  Stock_Quantity
# 0       P001            Laptop  Electronics    800              50
# 1       P002        Smartphone  Electronics    600             200
# 2       P003      Office Chair    Furniture    150             100
# 3       P004          Notebook   Stationery      5             500
# 4       P005  Wireless Headset  Electronics    100             150

# %%
products.shape #3. Show the number of rows and columns
# Out:
# (5, 5)

# %%
products.isna().sum() #4. Check if there are missing values (NaN)
# Out:
# Product_ID        0
# Product_Name      0
# Category          0
# Price             0
# Stock_Quantity    0
# dtype: int64

# %%
products.duplicated().sum() #Check for duplicate rows
# Out:
# np.int64(0)

# %%
products.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
products.describe() #6. Show summary statistics (even if some columns are numbers)
# Out:
#             Price  Stock_Quantity
# count    5.000000        5.000000
# mean   331.000000      200.000000
# std    348.109178      176.776695
# min      5.000000       50.000000
# 25%    100.000000      100.000000
# 50%    150.000000      150.000000
# 75%    600.000000      200.000000
# max    800.000000      500.000000

# %%
products["Category"].nunique() #Find how many unique categories there are:
# Out:
# 3

# %%
products["Category"].unique() #And list them:
# Out:
# array(['Electronics', 'Furniture', 'Stationery'], dtype=object)

# %%
products.columns #Show column names
# Out:
# Index(['Product_ID', 'Product_Name', 'Category', 'Price', 'Stock_Quantity'], dtype='object')

# %%
products.sort_values("Price", ascending=False) #2️⃣ Sort products by price (highest first)
# Out:
#   Product_ID      Product_Name     Category  Price  Stock_Quantity
# 0       P001            Laptop  Electronics    800              50
# 1       P002        Smartphone  Electronics    600             200
# 2       P003      Office Chair    Furniture    150             100
# 4       P005  Wireless Headset  Electronics    100             150
# 3       P004          Notebook   Stationery      5             500

# %%
products[products["Price"] > 100] #3️⃣ Filter only products with price greater than 100
# Out:
#   Product_ID  Product_Name     Category  Price  Stock_Quantity
# 0       P001        Laptop  Electronics    800              50
# 1       P002    Smartphone  Electronics    600             200
# 2       P003  Office Chair    Furniture    150             100

# %%
products["Category"].value_counts()#4️⃣ Count how many products in each category
# Out:
# Category
# Electronics    3
# Furniture      1
# Stationery     1
# Name: count, dtype: int64
